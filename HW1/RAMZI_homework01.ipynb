# %%
# DAT5 - Homework01
# Ramzi Ramey

# %%
import numpy as np

# %%
import pandas as pd

# %%
ls data/
# Out:
# housing-data.csv*  titanic-train.csv*

# %%
data = pd.read_csv('data/titanic-train.csv')

# %%
data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex  Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male   22      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female   38      1
# 2                             Heikkinen, Miss. Laina  female   26      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female   35      1
# 4                           Allen, Mr. William Henry    male   35      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S
#
# ...

# %% [markdown]
# ### # 1. How many passengers are in our passenger list?

# %%
data['PassengerId'].count()
# Out:
# 891

# %%
# or
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 891 entries, 0 to 890
# Data columns (total 12 columns):
# PassengerId    891 non-null int64
# Survived       891 non-null int64
# Pclass         891 non-null int64
# Name           891 non-null object
# Sex            891 non-null object
# Age            714 non-null float64
# SibSp          891 non-null int64
# Parch          891 non-null int64
# Ticket         891 non-null object
# Fare           891 non-null float64
# Cabin          204 non-null object
# Embarked       889 non-null object
# dtypes: float64(2), int64(5), object(5)

# %% [markdown]
# ### # 2. What is the overall survival rate?

# %%
data['Survived'].sum()
# Out:
# 342

# %%
survive_rate_all = float(data['Survived'].sum()) / (data['PassengerId'].count())
print survive_rate_all
# Out:
# 0.383838383838

# %% [markdown]
# ### # 3. How many male passengers were onboard?
#
# # 4. How many female passengers were onboard?

# %%
data[data.Sex == 'male'].head()
# Out:
#    PassengerId  Survived  Pclass                            Name   Sex  Age  \
# 0            1         0       3         Braund, Mr. Owen Harris  male   22
# 4            5         0       3        Allen, Mr. William Henry  male   35
# 5            6         0       3                Moran, Mr. James  male  NaN
# 6            7         0       1         McCarthy, Mr. Timothy J  male   54
# 7            8         0       3  Palsson, Master. Gosta Leonard  male    2
#
#    SibSp  Parch     Ticket     Fare Cabin Embarked
# 0      1      0  A/5 21171   7.2500   NaN        S
# 4      0      0     373450   8.0500   NaN        S
# 5      0      0     330877   8.4583   NaN        Q
# 6      0      0      17463  51.8625   E46        S
# 7      3      1     349909  21.0750   NaN        S
#
# [5 rows x 12 columns]

# %%
data[data.Sex == 'male'].count()
# Out:
# PassengerId    577
# Survived       577
# Pclass         577
# Name           577
# Sex            577
# Age            453
# SibSp          577
# Parch          577
# Ticket         577
# Fare           577
# Cabin          107
# Embarked       577
# dtype: int64

# %%
data[data.Sex == 'female'].count()
# Out:
# PassengerId    314
# Survived       314
# Pclass         314
# Name           314
# Sex            314
# Age            261
# SibSp          314
# Parch          314
# Ticket         314
# Fare           314
# Cabin           97
# Embarked       312
# dtype: int64

# %%
## Answer:  577 male passengers  and  314 females

# %% [markdown]
# ### # 5. What is the overall survival rate of male passengers?
# # 6. What is the overall survival rate of female passengers?

# %%
data[['Survived','Sex']].head()
# Out:
#    Survived     Sex
# 0         0    male
# 1         1  female
# 2         1  female
# 3         1  female
# 4         0    male
#
# [5 rows x 2 columns]

# %%
survival_by_sex = data[['Survived','Sex']]
survival_by_sex[survival_by_sex.Sex == 'male']
# Out:
#     Survived   Sex
# 0          0  male
# 4          0  male
# 5          0  male
# 6          0  male
# 7          0  male
# 12         0  male
# 13         0  male
# 16         0  male
# 17         1  male
# 20         0  male
# 21         1  male
# 23         1  male
# 26         0  male
# 27         0  male
# 29         0  male
# 30         0  male
# 33         0  male
# 34         0  male
# 35         0  male
# 36         1  male
# 37         0  male
# 42         0  male
# 45         0  male
# 46         0  male
# 48         0  male
# 50         0  male
# 51         0  male
# 54         0  male
# 55         1  male
# 57         0  male
# 59         0  male
# 60         0  male
# 62         0  male
# 63         0  male
# 64         0  male
# 65         1  male
# 67         0  male
# 69         0  male
# 70         0  male
# 72         0  male
# 73         0  male
# 74         1  male
# 75         0  male
# 76         0  male
# 77         0  male
# 78         1  male
# ...

# %%
survival_by_sex[survival_by_sex.Sex == 'male'].mean()
# Out:
# Survived    0.188908
# dtype: float64

# %%
## is this always the same as manual calculation?
x = survival_by_sex
float(x.Survived[x.Sex == 'male'].sum()) / (x.Survived[x.Sex == 'male'].count())
# Out:
# 0.18890814558058924

# %%
x[x.Sex == 'female'].mean()
# Out:
# Survived    0.742038
# dtype: float64

# %%
# Answer:  male survival rate was 18.89%,   female rate was 74.20%

# %% [markdown]
# ### #7. What is the average age of all passengers onboard?

# %%
data.Age
# Out:
# 0     22
# 1     38
# 2     26
# 3     35
# 4     35
# 5    NaN
# 6     54
# 7      2
# 8     27
# 9     14
# 10     4
# 11    58
# 12    20
# 13    39
# 14    14
# ...
# 876    20
# 877    19
# 878   NaN
# 879    56
# 880    25
# 881    33
# 882    22
# 883    28
# 884    25
# 885    39
# 886    27
# 887    19
# 888   NaN
# 889    26
# 890    32
# Name: Age, Length: 891, dtype: float64

# %%
data['Age'].describe()
# Out:
# count    714.000000
# mean      29.699118
# std       14.526497
# min        0.420000
# 25%       20.125000
# 50%       28.000000
# 75%       38.000000
# max       80.000000
# Name: Age, dtype: float64

# %%
# Answer seems to be average age of 29.7
#
# even though this necessarily leaves out 177 passengers with no Age recorded (NaN)

# %%
# a. How did you calculate this average age?
# b. Did you encounter any problems with this calculation?
# c. If so, how did you address any problems?

# %%
# I just used the standard pandas mean() statistic for that column, via describe(). 
# I know this is supposed to ignore any null values in the calculation. So what more can I do if 
# we really don't know the missing ages of the 177 people?

# OK I check below to see what these null-Age passengers look like:

# %%
data[['Survived','Age','Sex','Name']][pd.isnull(data.Age)]
# Out:
#      Survived  Age     Sex                                             Name
# 5           0  NaN    male                                 Moran, Mr. James
# 17          1  NaN    male                     Williams, Mr. Charles Eugene
# 19          1  NaN  female                          Masselmani, Mrs. Fatima
# 26          0  NaN    male                          Emir, Mr. Farred Chehab
# 28          1  NaN  female                    O'Dwyer, Miss. Ellen "Nellie"
# 29          0  NaN    male                              Todoroff, Mr. Lalio
# 31          1  NaN  female   Spencer, Mrs. William Augustus (Marie Eugenie)
# 32          1  NaN  female                         Glynn, Miss. Mary Agatha
# 36          1  NaN    male                                 Mamee, Mr. Hanna
# 42          0  NaN    male                              Kraeff, Mr. Theodor
# 45          0  NaN    male                         Rogers, Mr. William John
# ...

# %% [markdown]
# ### # 8. What is the average age of passengers who survived?
# # 9. What is the average age of passengers who did not survive?

# %%
survival_by_age = data[['Survived','Sex', 'Age']]
survival_by_age.head()
# Out:
#    Survived     Sex  Age
# 0         0    male   22
# 1         1  female   38
# 2         1  female   26
# 3         1  female   35
# 4         0    male   35
#
# [5 rows x 3 columns]

# %%
survival_by_age[survival_by_age.Survived == 0].describe()
# Out:
#        Survived         Age
# count       549  424.000000
# mean          0   30.626179
# std           0   14.172110
# min           0    1.000000
# 25%           0   21.000000
# 50%           0   28.000000
# 75%           0   39.000000
# max           0   74.000000
#
# [8 rows x 2 columns]

# %%
survival_by_age[survival_by_age.Survived == 1].describe()
# Out:
#        Survived         Age
# count       342  290.000000
# mean          1   28.343690
# std           0   14.950952
# min           1    0.420000
# 25%           1   19.000000
# 50%           1   28.000000
# 75%           1   36.000000
# max           1   80.000000
#
# [8 rows x 2 columns]

# %%
print 342 + 549    # is that all the passengers?
# Out:
# 891

# %%
# Answer:  Mean age of those who survived: 28.3
#          Mean age of those who died: 30.6

# %% [markdown]
# ### # 10. At this (early) point in our analysis, what might you infer about any patterns you are seeing?

# %%
# All I can really infer is that women were MUCH more likely to survive
# (allowed to board life boats first, I presume.)
# And that those who survived tended (slightly) to be younger, while
# while those who died tended (slightly) to be older

# %% [markdown]
# ### # 11. How many passengers are in each of the three classes of service (e.g. First, Second, Third?)

# %%
data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex  Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male   22      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female   38      1
# 2                             Heikkinen, Miss. Laina  female   26      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female   35      1
# 4                           Allen, Mr. William Henry    male   35      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S
#
# ...

# %%
survival_by_Class = data[['Survived', 'Pclass', 'Sex', 'Age']]
survival_by_Class.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 891 entries, 0 to 890
# Data columns (total 4 columns):
# Survived    891 non-null int64
# Pclass      891 non-null int64
# Sex         891 non-null object
# Age         714 non-null float64
# dtypes: float64(1), int64(2), object(1)

# %%
for i in range(1,4):
    print i
    print survival_by_Class[survival_by_Class.Pclass == i].count()
# Out:
# 1
# Survived    216
# Pclass      216
# Sex         216
# Age         186
# dtype: int64
# 2
# Survived    184
# Pclass      184
# Sex         184
# Age         173
# dtype: int64
# 3
# Survived    491
# Pclass      491
# Sex         491
# Age         355
# dtype: int64

# %%
print 216+184+491
# Out:
# 891

# %%
# Answer:
#  First Class:  216 passengers
#  Second Class: 184 passengers
#  Third Class:  491 passengers

# %% [markdown]
# ### # 12. What is the survival rate for passengers in each of the three classes of service?

# %%
for i in range(1,4):
    print i
    print survival_by_Class[survival_by_Class.Pclass == i].mean()
# Out:
# 1
# Survived     0.629630
# Pclass       1.000000
# Age         38.233441
# dtype: float64
# 2
# Survived     0.472826
# Pclass       2.000000
# Age         29.877630
# dtype: float64
# 3
# Survived     0.242363
# Pclass       3.000000
# Age         25.140620
# dtype: float64

# %%
# Answer:
#  First Class:  63.0% survival rate
#  Second Class: 47.3% survival rate
#  Third Class:  24.2% survival rate

# %% [markdown]
# ### # 13. Continuing with 10, what else might you conclude?

# %%
# Answer:
# It seems that the higher the Passenger class a person was in, the more likely to survive.
# I guess they got to get on the boats first, before the poor people.

# %% [markdown]
# ### # 14. Last, if we were to build a predictive model, which features in the data do you think we should include in the model and which can we leave out? Why?

# %%
data[0:1]
# Out:
#    PassengerId  Survived  Pclass                     Name   Sex  Age  SibSp  \
# 0            1         0       3  Braund, Mr. Owen Harris  male   22      1
#
#    Parch     Ticket  Fare Cabin Embarked
# 0      0  A/5 21171  7.25   NaN        S
#
# [1 rows x 12 columns]

# %%
# Answer:
# We should definitely include:  Pclass, Sex, Age, since we already determined those can reveal very
# different survival rates.

# We should probably include SibSp, Parch -- since whether someone had a spouse/sibling/child might
# very much also have affected their priority on getting on a life boat

# We should include NAME, to use it to derive other features like title, which might also determine 
# social standing somehow?

# At this point I suspect we could leave out Ticket, Fare, and Embarked (city), b/c those
# probably have little signal to what would have happened in the panic of the evacuation.

# I'd leave Cabin in there-- it's possible your position on the boat (front vs rear) etc could have
# an effect on your chance of survival.
